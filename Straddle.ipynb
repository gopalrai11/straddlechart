# %%
pip install nsepy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade git+https://github.com/StreamAlpha/pynse.git
# Out:
# ...
#   Cloning https://github.com/StreamAlpha/pynse.git to c:\users\gopal\appdata\local\temp\pip-req-build-cma5f1i4
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone -q https://github.com/StreamAlpha/pynse.git 'C:\Users\gopal\AppData\Local\Temp\pip-req-build-cma5f1i4'

# %%
import pandas as pd
import numpy as np

# %%
from pynse import *
import datetime as dt
import logging
logging.basicConfig(level=logging.DEBUG)


nse=Nse()
print(nse)
# Out:
# INFO:pynse.core:pyNse cache size: (6.83, 'MB').
# You may want to run `nse.clear_data()` if running low on disk space.
# ...

# %%
import time
import matplotlib.pyplot as plt

# %%
t = time.localtime()
current_time = time.strftime("%H:%M:%S", t)
print(current_time)
# Out:
# 15:14:14

# %%
# %matplotlib notebook
plt.rcParams['animation.html'] = 'jshtml'
# Out:
# DEBUG:matplotlib.pyplot:Loaded backend nbAgg version unknown.

# %%
fig = plt.figure()
ax = fig.add_subplot(111,title='straddle chart')
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
i = 9.15
x, y = [], []

while True:
    hdfc=nse.get_quote('NIFTY', segment=Segment.OPT, optionType=OptionType.CE, strike=18000)
    hdfc2=pd.DataFrame(hdfc,[18000])

    hdfc=nse.get_quote('NIFTY', segment=Segment.OPT, optionType=OptionType.PE, strike=18000)
    hdfc1=pd.DataFrame(hdfc,[18000])


    total=(hdfc1['lastPrice'] + hdfc2['lastPrice'])
    total.head()
    x.append(i)
    y.append(total.head())
    
    ax.plot(x, y, color='b')
    
    fig.canvas.draw()
    
    ax.set_xlim(left=max(0, i-50), right=i+50)
    
    time.sleep(180)
    i += 1
# Out:
# INFO:pynse.core:downloading quote for NIFTY OPT
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 41076
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=NIFTY HTTP/1.1" 200 211854
# INFO:pynse.core:downloading quote for NIFTY OPT
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 41074
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET /api/quote-derivative?symbol=NIFTY HTTP/1.1" 200 211854
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:pynse.core:downloading quote for NIFTY OPT
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.nseindia.com:443
# DEBUG:urllib3.connectionpool:https://www.nseindia.com:443 "GET / HTTP/1.1" 200 41109
# ...

# %%
plt.close()
